# %%
# Initial Imports

import flair #<------- new NLP module not used in class
from flair.data import Sentence

from flair.models import SequenceTagger
import os
import pandas as pd
from newsapi import NewsApiClient
import json
from dotenv import load_dotenv
from pathlib import Path
load_dotenv()
from path import Path
curr_date = str(pd.to_datetime('today').date()) #<------store todays date in a variable

# %%
# Initiate a FinTech Class Sentiment Model

fintech_sentiment_model = flair.models.TextClassifier.load('en-sentiment')
# Out:
# 2022-01-03 19:05:35,446 loading file C:\Users\Airma\.flair\models\sentiment-en-mix-distillbert_4.pt

# %%
# Class Participation

chapter_1 = "  "
chapter_2 = "  "
chapter_3 = "  "
chapter_4 = "  "
chapter_5 = "  "

# Combine chapters

fintech_class_movie_plot = ("One day a nice person went for a walk on a nice day." + chapter_1 + chapter_2 + chapter_3 + chapter_4 + chapter_5)



# Run the model

results = flair.data.Sentence(fintech_class_movie_plot)
fintech_sentiment_model.predict(results)

#Define the results

sentiment = results.labels[0].value
confidence = round((results.labels[0].score) * 100, 2) #<-------Convert to percentage and round to 3 decimal places

confidence = str(confidence) #<---------- Convert to string

print(fintech_class_movie_plot)

print("The resulting sentiment is " + sentiment + " and the resulting confidence level is " + confidence + "%")
# Out:
# One day a nice person went for a walk on a nice day. Then he ate an apple.
# The resulting sentiment is POSITIVE and the resulting confidence level is 92.26%

# %%
# Output to PDF

from fpdf import FPDF # <----------- new module

#Initialize a new PDF

pdf = FPDF()
pdf.add_page()
pdf.set_font('Arial', 'B', 16)
pdf.cell(10, 10, "This is the movie plot that was created on " + curr_date)
pdf.cell(10, 30, fintech_class_movie_plot)
pdf.cell(10, 80, "The results of a Flair Sentiment Analysis are as follows:")
pdf.cell(10, 100, "Sentiment Score " + sentiment)
pdf.cell(10, 120, "Confidence Score " + confidence + "%")
pdf.output('flair_demo.pdf')
# Out:
# ''

# %%
# Initiate a Movie Sentiment Model

movie_sentiment_model = flair.models.TextClassifier.load('en-sentiment')
# Out:
# 2021-12-30 18:23:55,009 loading file C:\Users\Airma\.flair\models\sentiment-en-mix-distillbert_4.pt

# %%
# Set path to movie quotes CSV

movie_csv = Path("sentiment_moviequotes.csv")

# %%
# Import movie quotes CSV

sentiment_moviequotes = pd.read_csv(movie_csv)

# %%
sentiment_moviequotes
# Out:
#          movie_or_book_title  \
# 0                 Braveheart
# 1                 The Matrix
# 2          Full Metal Jacket
# 3  The Count of Monte Cristo
# 4           Romeo and Juliet
# 5    The Blair Witch Project
# 6                 The Matrix
# 7               Office Space
# 8               Office Space
# 9                  Westworld
#
#                                                quote
# 0    This Wallace, he doesn’t even have a knighth...
# 1  Neo, I'm not afraid anymore. The Oracle told m...
# 2  I am Gunnery Sergeant Hartman, your senior dri...
# 3  The heart breaks when it has swelled too much ...
# 4  From ancient grudge break to new mutiny, where...
# 5  I’m scared to close my eyes; I’m scared to ope...
# 6  You Take The Red Pill - You Stay In Wonderland...
# 7  Now, you know it's up to you whether or not yo...
# 8   "Oh oh and I almost forgot. I'm also gonna ne...
# 9   "I always trusted code more than people anyway."

# %%
# Initialize lists for movie quotes

movie_sentiment = []
movie_confidence = []


# Run Sentiment analysis on collected news sentences

for sentence in sentiment_moviequotes["quote"]:
    if sentence.strip() == "":
        movie_sentiment.append("")
        movie_confidence.append("")
        
    else:
        sample = flair.data.Sentence(sentence)
        movie_sentiment_model.predict(sample)
        movie_sentiment.append(sample.labels[0].value)
        movie_confidence.append(sample.labels[0].score)

# %%
# New dataframe to collect sentiment and confidence

sentiment_moviequotes['sentiment'] = movie_sentiment
sentiment_moviequotes['confidence'] = movie_confidence

# %%
sentiment_moviequotes
# Out:
#          movie_or_book_title  \
# 0                 Braveheart
# 1                 The Matrix
# 2          Full Metal Jacket
# 3  The Count of Monte Cristo
# 4           Romeo and Juliet
# 5    The Blair Witch Project
# 6                 The Matrix
# 7               Office Space
# 8               Office Space
# 9                  Westworld
#
#                                                quote sentiment  confidence
# 0    This Wallace, he doesn’t even have a knighth...  POSITIVE    0.936748
# 1  Neo, I'm not afraid anymore. The Oracle told m...  POSITIVE    0.999391
# 2  I am Gunnery Sergeant Hartman, your senior dri...  POSITIVE    0.619646
# 3  The heart breaks when it has swelled too much ...  NEGATIVE    0.881627
# 4  From ancient grudge break to new mutiny, where...  NEGATIVE    0.985824
# 5  I’m scared to close my eyes; I’m scared to ope...  POSITIVE    0.606712
# 6  You Take The Red Pill - You Stay In Wonderland...  POSITIVE    0.999108
# 7  Now, you know it's up to you whether or not yo...  POSITIVE    0.997503
# 8   "Oh oh and I almost forgot. I'm also gonna ne...  POSITIVE    0.565588
# 9   "I always trusted code more than people anyway."  POSITIVE    0.993092

# %%
api_key = os.getenv("news_api_key")

# %%
# Create a newsapi client
newsapi = NewsApiClient(api_key=api_key)

# %%
# Fetch Binance Coin Headlines

bnb_news = newsapi.get_everything(q="Binance", language="en", sort_by="relevancy")
bnb_news
# Out:
# {'status': 'ok',
#  'totalResults': 855,
#  'articles': [{'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': None,
#    'title': 'Binance affiliate says will withdraw Singapore licence application - Reuters',
#    'description': "The Singapore affiliate of Binance, one of the world's largest cryptocurrency exchanges, said in a statement on Monday it will withdraw its local license application and wind down its digital payment token business in the city-state.",
#    'url': 'https://www.reuters.com/markets/currencies/binance-affiliate-says-will-withdraw-singapore-licence-application-2021-12-13/',
#    'urlToImage': 'https://www.reuters.com/resizer/qpZhRL1yNeVWVXC9uu_Nn5ZPHI8=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/5VUZIYGEZVKCDICHODGO4EC64Q.jpg',
#    'publishedAt': '2021-12-13T02:54:00Z',
#    'content': "HONG KONG, Dec 13 (Reuters) - The Singapore affiliate of Binance, one of the world's largest cryptocurrency exchanges, said in a statement on Monday it will withdraw its local license application and… [+1916 chars]"},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': None,
#    'title': 'No, Twitter not a valid way to serve a crypto suit on Binance execs, judge rules - Reuters',
#    'description': 'Yi He, a cofounder of the cryptocurrency exchange Binance Capital Management Co. Ltd, has a little joke in her <a href="https://twitter.com/heyibinance" target="_blank">Twitter bio</a>: She lists her location as Mars. Binance’s chief growth officer, Ted Lin, …',
#    'url': 'https://www.reuters.com/legal/litigation/no-twitter-not-valid-way-serve-crypto-suit-binance-execs-judge-rules-2021-12-16/',
#    'urlToImage': 'https://www.reuters.com/resizer/uDgqqPP-w0flayO1Dm5Y9FUfIfk=/728x381/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/5GTT34JHSBO3DO3CGZPWAUEK4A.jpg',
#    'publishedAt': '2021-12-16T21:34:00Z',
#    'content': 'The company and law firm names shown above are generated automatically based on the text of the article. We are improving this feature as we continue to test and develop in beta. We welcome feedback,… [+6221 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': None,
#    'title': 'Crypto exchange Binance signs agreement with Dubai World Trade Centre - Reuters',
#    'description': 'Cryptocurrency exchange Binance on Tuesday said it has signed a cooperation agreement with Dubai World Trade Centre Authority (DWTCA), which is working to establish an international virtual asset ecosystem.',
#    'url': 'https://www.reuters.com/world/middle-east/crypto-exchange-binance-signs-agreement-with-dubai-world-trade-centre-2021-12-21/',
#    'urlToImage': 'https://www.reuters.com/resizer/qpZhRL1yNeVWVXC9uu_Nn5ZPHI8=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/5VUZIYGEZVKCDICHODGO4EC64Q.jpg',
#    'publishedAt': '2021-12-21T09:08:00Z',
#    'content': 'Biance app is seen on a smartphone in this illustration taken, July 13, 2021. REUTERS/Dado Ruvic/IllustrationDUBAI, Dec 21 (Reuters) - Cryptocurrency exchange Binance on Tuesday said it has signed a … [+585 chars]'},
#   {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'author': 'snagarajan@businessinsider.com (Shalini Nagarajan)',
#    'title': 'Binance revives plans for a UK launch after winning over the financial regulators that banned it',
#    'description': "Binance's relations with the FCA have improved ever since its UK-based marketplace was banned from conducting regulated activity in June, Zhao said.",
#    'url': 'https://markets.businessinsider.com/news/currencies/binance-uk-launch-changpeng-zhao-regulatory-hurdle-fca-compliance-crypto-2021-12',
#    'urlToImage': 'https://images2.markets.businessinsider.com/61011bcaf350d500195952b4?format=jpeg',
#    'publishedAt': '2021-12-06T15:25:21Z',
#    'content': 'Binance CEO, Changpeng Zhao.Andrey Rudakov/Bloomberg via Getty Images\r\nCrypto exchange Binance is reviving its plan to set up a UK arm, after making efforts to win over the financial regulator that c… [+2741 chars]'},
#   {'source': {'id': None, 'name': 'VentureBeat'},
#    'author': 'Dean Takahashi',
#    'title': 'Alethea AI, BeingAI, and Binance NFT launch NFT-based AI game characters',
#    'description': 'Alethea AI and BeingAI are collaborating with the Binance NFT marketplace to introduce the AI game characters that are based on NFTs.',
#    'url': 'https://venturebeat.com/2021/12/06/alethea-ai-beingai-and-binance-nft-launch-nft-based-ai-game-characters/',
#    'urlToImage': 'https://venturebeat.com/wp-content/uploads/2021/12/BEING-AI.jpg?w=1200&strip=all',
#    'publishedAt': '2021-12-06T17:00:09Z',
#    'content': 'Join gaming leaders, alongside GamesBeat and Facebook Gaming, for their 2nd Annual GamesBeat &amp; Facebook Gaming Summit | GamesBeat: Into the Metaverse 2 this upcoming January 25-27, 2022. Learn mo… [+1225 chars]'},
#   {'source': {'id': None, 'name': 'Slashdot.org'},
#    'author': 'EditorDavid',
#    'title': 'Another Crypto Heist: $150M+ Stolen from Trading Platform BitMart',
#    'description': '"We have identified a large-scale security breach..." the official announcement begins. \n\nCNBC reports:\n\nHackers have taken $196 million from crypto trading platform BitMart, a security firm said Saturday. \n\nBitMart confirmed the hack in an official statement…',
#    'url': 'https://yro.slashdot.org/story/21/12/06/0147215/another-crypto-heist-150m-stolen-from-trading-platform-bitmart',
#    'urlToImage': 'https://a.fsdn.com/sd/topics/crime_64.png',
#    'publishedAt': '2021-12-06T01:51:00Z',
#    'content': '"We have identified a large-scale security breach..." the official announcement begins. CNBC reports:\r\nHackers have taken $196 million from crypto trading platform BitMart, a security firm said Satur… [+1059 chars]'},
#   {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'author': 'ndailey@insider.com (Natasha Dailey)',
#    'title': "A California democrat's joke during Wednesday's crypto hearing has spurred the creation of 'mongoose coin'",
#    'description': '"Will mongoose coin always have a value?" Sherman said at the hearing. "I don\'t know. I just made it up. It\'s a joke."',
#    'url': 'https://www.businessinsider.com/crypto-mongoose-coin-democrat-congressional-hearing-cryptocurrency-2021-12',
#    'urlToImage': 'https://images2.markets.businessinsider.com/61b200ffd7efa6001889edbd?format=jpeg',
#    'publishedAt': '2021-12-09T14:34:34Z',
#    'content': 'Family of banded mongoose at Masai Mara National Park, Kenya. Getty images stock photoGetty images stock photo\r\nThe Congressional hearing on crypto spurred a new meme cryptocurrency: mongoose coin.\r\n… [+1747 chars]'},
#   {'source': {'id': None, 'name': 'Slashdot.org'},
#    'author': 'msmash',
#    'title': 'Football Fans Spending Millions on Club Crypto-tokens',
#    'description': 'Football clubs have potentially made hundreds of millions of dollars selling controversial crypto "fan tokens." From a report: Analysis commissioned by BBC News estimates more than $350m has been spent on the virtual currencies. Some of the tokens are markete…',
#    'url': 'https://slashdot.org/story/21/12/10/1733241/football-fans-spending-millions-on-club-crypto-tokens',
#    'urlToImage': 'https://a.fsdn.com/sd/topics/business_64.png',
#    'publishedAt': '2021-12-10T17:33:00Z',
#    'content': 'Analysis commissioned by BBC News estimates more than $350m has been spent on the virtual currencies. Some of the tokens are marketed as offering real-world perks to the buyer. But critics say these … [+784 chars]'},
#   {'source': {'id': 'engadget', 'name': 'Engadget'},
#    'author': 'Mat Smith',
#    'title': 'The Morning After: Is ‘Halo: Infinite’ worth the wait?',
#    'description': 'The wait is finally over. After a year-long delay, Xbox’s iconic hero, Master Chief, is back. With Halo Infinite, there are new toys and fight mechanics, while many players will also benefit from major cosmetic upgrades if they’re playing on the newest Micros…',
#    'url': 'https://www.engadget.com/the-morning-after-apple-fights-russias-app-store-ruling-121550694.html',
#    'urlToImage': 'https://s.yimg.com/os/creatr-uploaded-images/2021-12/172ea620-5623-11ec-af7f-b718a74dfe6d',
#    'publishedAt': '2021-12-06T12:15:50Z',
#    'content': 'The wait is finally over. After a year-long delay, Xboxs iconic hero, Master Chief, is back. With Halo Infinite, there are new toys and fight mechanics, while many players will also benefit from majo… [+4439 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': None,
#    'title': 'Coinbase says connectivity issues fixed, investigating delays - Reuters',
#    'description': 'Coinbase Global Inc <a href="https://www.reuters.com/companies/COIN.O" target="_blank">(COIN.O)</a> said on a <a href="https://twitter.com/CoinbaseSupport/status/1471017964225048576" target="_blank">Twitter post</a> on Wednesday it has resolved the connectivi…',
#    'url': 'https://www.reuters.com/markets/us/coinbase-says-connectivity-issues-fixed-investigating-delays-2021-12-15/',
#    'urlToImage': 'https://www.reuters.com/resizer/O41cIC-n0Bs8kVS732tgDy9vfws=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/SXNYHTTM5NLNRO3FTWUWUSDAAY.jpg',
#    'publishedAt': '2021-12-15T13:11:00Z',
#    'content': 'People watch as the logo for Coinbase Global Inc, the biggest U.S. cryptocurrency exchange, is displayed on the Nasdaq MarketSite jumbotron at Times Square in New York, U.S., April 14, 2021. REUTERS/… [+1154 chars]'},
#   {'source': {'id': None, 'name': 'MakeUseOf'},
#    'author': 'Katie Rees',
#    'title': 'Binance Lite vs. Binance Professional: What’s the Difference?',
#    'description': "Binance is the largest cryptocurrency exchange in the world. What's the difference between its Lite and Professional versions?",
#    'url': 'https://www.makeuseof.com/binance-lite-vs-binance-professional/',
#    'urlToImage': 'https://static1.makeuseofimages.com/wordpress/wp-content/uploads/2021/10/binance-blockchain-display.jpg',
#    'publishedAt': '2021-12-07T15:00:12Z',
#    'content': 'Today, the Binance cryptocurrency exchange is the biggest in the world, with over 20 million users in a range of different countries. This popular exchange also offers a mobile app to buy, sell, and … [+6873 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': None,
#    'title': 'Crypto startup Nansen raises $75 mln in early-stage funding led by Accel - Reuters',
#    'description': 'Blockchain analytics firm Nansen on Thursday raised $75 million in an early stage funding round led by venture capital firm Accel, with participation from Andreessen Horowitz and technology investor Tiger Global.',
#    'url': 'https://www.reuters.com/markets/us/crypto-startup-nansen-raises-75-mln-early-stage-funding-led-by-accel-2021-12-16/',
#    'urlToImage': 'https://www.reuters.com/pf/resources/images/reuters/reuters-default.png?d=63',
#    'publishedAt': '2021-12-16T13:00:00Z',
#    'content': 'Dec 16 (Reuters) - Blockchain analytics firm Nansen on Thursday raised $75 million in an early stage funding round led by venture capital firm Accel, with participation from Andreessen Horowitz and t… [+1454 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': None,
#    'title': 'Factors to watch - December 28 - Reuters',
#    'description': 'Here are some factors that may affect Middle East stock markets on Tuesday. Reuters has not verified the press reports and does not vouch for their accuracy.',
#    'url': 'https://www.reuters.com/markets/asia/factors-watch-december-28-2021-12-28/',
#    'urlToImage': 'https://www.reuters.com/pf/resources/images/reuters/reuters-default.png?d=66',
#    'publishedAt': '2021-12-28T04:31:00Z',
#    'content': 'DUBAI, Dec 28 (Reuters) - Here are some factors that may affect Middle East stock markets on Tuesday. Reuters has not verified the press reports and does not vouch for their accuracy.\r\nINTERNATIONAL/… [+1667 chars]'},
#   {'source': {'id': None, 'name': 'Entrepreneur'},
#    'author': 'Chloe Arrojado',
#    'title': 'Bitmart Reportedly Loses Nearly $200 Million in Massive Hack',
#    'description': 'The cryptocurrency trading platform is suspending withdrawals until further notice.',
#    'url': 'https://www.entrepreneur.com/article/400910',
#    'urlToImage': 'https://assets.entrepreneur.com/content/3x2/2000/1638805758-shutterstock-1452780077.jpg',
#    'publishedAt': '2021-12-06T15:49:00Z',
#    'content': "Amid the news of Bitcoin's price plunge\xa0on Saturday, crypto investors are faced with more bad news.\xa0Over the weekend, a hacker reportedly took $196 million from cryptocurrency trading platform Bitmar… [+1445 chars]"},
#   {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'author': 'cshumba@insider.com (Camomile Shumba)',
#    'title': "BitMart says it's resumed crypto withdrawals three days after hackers stole almost $200 million in funds",
#    'description': 'Sheldon Xia, the founder of BitMart exchange, said on Twitter withdrawals would be resumed "step by step".',
#    'url': 'https://markets.businessinsider.com/news/currencies/bitmart-crypto-hack-exchange-resumed-withdrawals-millions-ether-bitcoin-sol-2021-12',
#    'urlToImage': 'https://images2.markets.businessinsider.com/61b0a4176531110019cf15ff?format=jpeg',
#    'publishedAt': '2021-12-08T12:57:21Z',
#    'content': 'HackerThana Prasongsin\r\nCrypto exchange BitMart said early on Wednesday it would gradually resume withdrawals, three days after hackers ran away with close to $200 million worth of funds from its cli… [+1464 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': None,
#    'title': 'Factors to watch - December 22 - Reuters',
#    'description': 'Here are some factors that may affect Middle East stock markets on Wednesday. Reuters has not verified the press reports and does not vouch for their accuracy.',
#    'url': 'https://www.reuters.com/markets/asia/factors-watch-december-22-2021-12-22/',
#    'urlToImage': 'https://www.reuters.com/pf/resources/images/reuters/reuters-default.png?d=66',
#    'publishedAt': '2021-12-22T04:37:00Z',
#    'content': 'DUBAI, Dec 22 (Reuters) - Here are some factors that may affect Middle East stock markets on Wednesday. Reuters has not verified the press reports and does not vouch for their accuracy.\r\nINTERNATIONA… [+1997 chars]'},
#   {'source': {'id': None, 'name': 'Entrepreneur'},
#    'author': 'Entrepreneur en Español',
#    'title': 'Hackers steal hundreds of millions of dollars worth of Bitmart cryptocurrencies',
#    'description': "The cybercriminals used a private key to access two of the company's Hot Wallets.",
#    'url': 'https://www.entrepreneur.com/article/401232',
#    'urlToImage': 'https://assets.entrepreneur.com/content/3x2/2000/1638891427-mika-baumeister-J5yoGZLdpSI-unsplash.jpg',
#    'publishedAt': '2021-12-07T16:05:23Z',
#    'content': 'Last night they robbed one of the best-known cryptocurrency exchanges and cybercriminals took around $ 200 million. Bitmart founder Sheldon Xia posted on Twitter that money had been extracted from tw… [+1793 chars]'},
#   {'source': {'id': None, 'name': 'Techmeme.com'},
#    'author': None,
#    'title': 'Multichain, which offers interoperability tools for blockchains including Ethereum, Binance Smart Chain, and Avalanche, raises a $60M seed led by Binance Labs (Helen Partz/Cointelegraph)',
#    'description': 'Helen Partz / Cointelegraph:\nMultichain, which offers interoperability tools for blockchains including Ethereum, Binance Smart Chain, and Avalanche, raises a $60M seed led by Binance Labs\xa0 —\xa0 Shortly after rebranding from Anyswap last week, Multichain raised …',
#    'url': 'https://www.techmeme.com/211221/p9',
#    'urlToImage': 'https://images.cointelegraph.com/images/1200_aHR0cHM6Ly9zMy5jb2ludGVsZWdyYXBoLmNvbS91cGxvYWRzLzIwMjEtMTIvOWI2ODg5YzgtMzhjNC00YWQyLWI2NDAtNjM2YzkwYzA4ODM5LmpwZw==.jpg',
#    'publishedAt': '2021-12-21T12:00:45Z',
#    'content': 'CB Insights Newsletter\r\n724,948 subscribers get our free newsletter to stay a step ahead on technology trends, venture capital, startups, and the industries of tomorrow.'},
#   {'source': {'id': None, 'name': 'The Guardian'},
#    'author': 'Richard Partington Economics correspondent',
#    'title': 'Bitcoin could become ‘worthless’, Bank of England warns',
#    'description': 'People investing in the cryptocurrency should be aware of risks, central bank saysThe Bank of England has said that bitcoin could be “worthless” and people investing in the digital currency should be prepared to lose everything.In a warning over the potential…',
#    'url': 'https://amp.theguardian.com/technology/2021/dec/14/bitcoin-could-become-worthless-bank-of-england-warns',
#    'urlToImage': 'https://i.guim.co.uk/img/media/dde432ebba7a190ced7b2df382000bcc015b9615/0_0_3500_2100/master/3500.jpg?width=1200&height=630&quality=85&auto=format&fit=crop&overlay-align=bottom%2Cleft&overlay-width=100p&overlay-base64=L2ltZy9zdGF0aWMvb3ZlcmxheXMvdGctZGVmYXVsdC5wbmc&enable=upscale&s=1c17c82a86bea284bef4bd100a95015b',
#    'publishedAt': '2021-12-14T17:52:36Z',
#    'content': 'The Bank of England has said that bitcoin could be worthless and people investing in the digital currency should be prepared to lose everything.\r\nIn a warning over the potential risks for investors, … [+3230 chars]'},
#   {'source': {'id': None, 'name': 'Fast Company'},
#    'author': 'Max Ufberg',
#    'title': 'Want to put Bitcoin in their stocking this year? Here’s how to gift crypto',
#    'description': 'If you’re looking for last-minute gift ideas, giving the gift of crypto is a lot easier than you might think. \nLooking for a holiday present that won’t fall victim to any supply-chain snafus? If so, there’s always crypto.Read Full Story',
#    'url': 'https://www.fastcompany.com/90706611/how-to-gift-crypto-bitcoin-nfts?partner=feedburner&utm_source=feedburner&utm_medium=feed&utm_campaign=feedburner+fastcompany&utm_content=feedburner',
#    'urlToImage': 'https://images.fastcompany.net/image/upload/w_1280,f_auto,q_auto,fl_lossy/wp-cms/uploads/2021/12/p-1-how-to-gift-crypto-bitcoin-nfts.jpg',
#    'publishedAt': '2021-12-16T06:00:25Z',
#    'content': 'Looking for a holiday present that won’t fall victim to any supply-chain snafus? If so, there’s always crypto.\r\nThe vast majority of Americans have never invested in or traded a cryptocurrency, but b… [+4033 chars]'}]}

# %%
df = pd.DataFrame.from_dict(bnb_news["articles"])


binance_df = df[["description"]]


binance_df
# Out:
#                                           description
# 0   The Singapore affiliate of Binance, one of the...
# 1   Yi He, a cofounder of the cryptocurrency excha...
# 2   Cryptocurrency exchange Binance on Tuesday sai...
# 3   Binance's relations with the FCA have improved...
# 4   Alethea AI and BeingAI are collaborating with ...
# 5   "We have identified a large-scale security bre...
# 6   "Will mongoose coin always have a value?" Sher...
# 7   Football clubs have potentially made hundreds ...
# 8   The wait is finally over. After a year-long de...
# 9   Coinbase Global Inc <a href="https://www.reute...
# 10  Binance is the largest cryptocurrency exchange...
# 11  Blockchain analytics firm Nansen on Thursday r...
# 12  Here are some factors that may affect Middle E...
# 13  The cryptocurrency trading platform is suspend...
# 14  Sheldon Xia, the founder of BitMart exchange, ...
# 15  Here are some factors that may affect Middle E...
# 16  The cybercriminals used a private key to acces...
# 17  Helen Partz / Cointelegraph:\nMultichain, whic...
# 18  People investing in the cryptocurrency should ...
# 19  If you’re looking for last-minute gift ideas, ...

# %%
# create a news Sentiment Model

news_sentiment_model = flair.models.TextClassifier.load('en-sentiment')
# Out:
# 2021-12-30 18:23:59,204 loading file C:\Users\Airma\.flair\models\sentiment-en-mix-distillbert_4.pt

# %%
# Initialize lists

binance_sentiment = []
binance_confidence = []


# Run Sentiment analysis on collected news sentences

for sentence in binance_df["description"]:
    if sentence.strip() == "":
        binance_sentiment.append("")
        binance_confidence.append("")
        
    else:
        sample = flair.data.Sentence(sentence)
        news_sentiment_model.predict(sample)
        binance_sentiment.append(sample.labels[0].value)
        binance_confidence.append(sample.labels[0].score)

# %%
# New column to collect sentiment and confidence

binance_df['sentiment'] = binance_sentiment
binance_df['confidence'] = binance_confidence
# Out:
# C:\Users\Airma\AppData\Local\Temp/ipykernel_8416/58193482.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   binance_df['sentiment'] = binance_sentiment
# C:\Users\Airma\AppData\Local\Temp/ipykernel_8416/58193482.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   binance_df['confidence'] = binance_confidence

# %%
binance_df
# Out:
#                                           description sentiment  confidence
# 0   The Singapore affiliate of Binance, one of the...  NEGATIVE    0.999621
# 1   Yi He, a cofounder of the cryptocurrency excha...  NEGATIVE    0.995340
# 2   Cryptocurrency exchange Binance on Tuesday sai...  POSITIVE    0.536603
# 3   Binance's relations with the FCA have improved...  POSITIVE    0.916237
# 4   Alethea AI and BeingAI are collaborating with ...  POSITIVE    0.987426
# 5   "We have identified a large-scale security bre...  NEGATIVE    0.999466
# 6   "Will mongoose coin always have a value?" Sher...  NEGATIVE    0.999763
# 7   Football clubs have potentially made hundreds ...  NEGATIVE    0.980816
# 8   The wait is finally over. After a year-long de...  POSITIVE    0.621667
# 9   Coinbase Global Inc <a href="https://www.reute...  NEGATIVE    0.861919
# 10  Binance is the largest cryptocurrency exchange...  POSITIVE    0.998292
# 11  Blockchain analytics firm Nansen on Thursday r...  POSITIVE    0.739658
# 12  Here are some factors that may affect Middle E...  NEGATIVE    0.999411
# 13  The cryptocurrency trading platform is suspend...  NEGATIVE    0.996753
# 14  Sheldon Xia, the founder of BitMart exchange, ...  NEGATIVE    0.999538
# 15  Here are some factors that may affect Middle E...  NEGATIVE    0.999438
# 16  The cybercriminals used a private key to acces...  NEGATIVE    0.853617
# 17  Helen Partz / Cointelegraph:\nMultichain, whic...  NEGATIVE    0.630773
# 18  People investing in the cryptocurrency should ...  NEGATIVE    0.999828
# 19  If you’re looking for last-minute gift ideas, ...  POSITIVE    0.943750

# %%
# Assign numerical values based on sentiment value

sentiment_numerical = []

for row in binance_df["sentiment"]:
    i = ""
    if row == "POSITIVE":
        i = 1
        sentiment_numerical.append(i)
    else:
        i = - 1
        sentiment_numerical.append(i)

binance_df["sentiment_numerical"] = sentiment_numerical

binance_df = binance_df.astype({"sentiment_numerical" : float})



binance_df
# Out:
# C:\Users\Airma\AppData\Local\Temp/ipykernel_8416/2963336444.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   binance_df["sentiment_numerical"] = sentiment_numerical
#                                           description sentiment  confidence  \
# 0   The Singapore affiliate of Binance, one of the...  NEGATIVE    0.999621
# 1   Yi He, a cofounder of the cryptocurrency excha...  NEGATIVE    0.995340
# 2   Cryptocurrency exchange Binance on Tuesday sai...  POSITIVE    0.536603
# 3   Binance's relations with the FCA have improved...  POSITIVE    0.916237
# 4   Alethea AI and BeingAI are collaborating with ...  POSITIVE    0.987426
# 5   "We have identified a large-scale security bre...  NEGATIVE    0.999466
# 6   "Will mongoose coin always have a value?" Sher...  NEGATIVE    0.999763
# 7   Football clubs have potentially made hundreds ...  NEGATIVE    0.980816
# 8   The wait is finally over. After a year-long de...  POSITIVE    0.621667
# 9   Coinbase Global Inc <a href="https://www.reute...  NEGATIVE    0.861919
# 10  Binance is the largest cryptocurrency exchange...  POSITIVE    0.998292
# 11  Blockchain analytics firm Nansen on Thursday r...  POSITIVE    0.739658
# 12  Here are some factors that may affect Middle E...  NEGATIVE    0.999411
# 13  The cryptocurrency trading platform is suspend...  NEGATIVE    0.996753
# 14  Sheldon Xia, the founder of BitMart exchange, ...  NEGATIVE    0.999538
# 15  Here are some factors that may affect Middle E...  NEGATIVE    0.999438
# 16  The cybercriminals used a private key to acces...  NEGATIVE    0.853617
# 17  Helen Partz / Cointelegraph:\nMultichain, whic...  NEGATIVE    0.630773
# 18  People investing in the cryptocurrency should ...  NEGATIVE    0.999828
# 19  If you’re looking for last-minute gift ideas, ...  POSITIVE    0.943750
#
#     sentiment_numerical
# 0                  -1.0
# 1                  -1.0
# 2                   1.0
# 3                   1.0
# 4                   1.0
# 5                  -1.0
# 6                  -1.0
# 7                  -1.0
# 8                   1.0
# 9                  -1.0
# 10                  1.0
# 11                  1.0
# 12                 -1.0
# 13                 -1.0
# 14                 -1.0
# 15                 -1.0
# 16                 -1.0
# 17                 -1.0
# 18                 -1.0
# 19                  1.0

# %%
#binance_df.to_csv("binance_test.csv")

# Create variable to store total confidence value
total_confidence_value = binance_df['confidence'].sum().astype(float)
print(total_confidence_value)
# Out:
# 18.059917211532593

# %%
# Add weighted sentiment
## Weighted sentiment takes the confidence value and divides by the total of confidence values to determine 
## how much weight that particular news article should influence the overal sentiment

weighted_sentiment = []



binance_df["weighted_sentiment"] = (binance_df["confidence"] * binance_df["sentiment_numerical"] / total_confidence_value)
    
    
    
binance_df
# Out:
#                                           description sentiment  confidence  \
# 0   The Singapore affiliate of Binance, one of the...  NEGATIVE    0.999621
# 1   Yi He, a cofounder of the cryptocurrency excha...  NEGATIVE    0.995340
# 2   Cryptocurrency exchange Binance on Tuesday sai...  POSITIVE    0.536603
# 3   Binance's relations with the FCA have improved...  POSITIVE    0.916237
# 4   Alethea AI and BeingAI are collaborating with ...  POSITIVE    0.987426
# 5   "We have identified a large-scale security bre...  NEGATIVE    0.999466
# 6   "Will mongoose coin always have a value?" Sher...  NEGATIVE    0.999763
# 7   Football clubs have potentially made hundreds ...  NEGATIVE    0.980816
# 8   The wait is finally over. After a year-long de...  POSITIVE    0.621667
# 9   Coinbase Global Inc <a href="https://www.reute...  NEGATIVE    0.861919
# 10  Binance is the largest cryptocurrency exchange...  POSITIVE    0.998292
# 11  Blockchain analytics firm Nansen on Thursday r...  POSITIVE    0.739658
# 12  Here are some factors that may affect Middle E...  NEGATIVE    0.999411
# 13  The cryptocurrency trading platform is suspend...  NEGATIVE    0.996753
# 14  Sheldon Xia, the founder of BitMart exchange, ...  NEGATIVE    0.999538
# 15  Here are some factors that may affect Middle E...  NEGATIVE    0.999438
# 16  The cybercriminals used a private key to acces...  NEGATIVE    0.853617
# 17  Helen Partz / Cointelegraph:\nMultichain, whic...  NEGATIVE    0.630773
# 18  People investing in the cryptocurrency should ...  NEGATIVE    0.999828
# 19  If you’re looking for last-minute gift ideas, ...  POSITIVE    0.943750
#
#     sentiment_numerical  weighted_sentiment
# 0                  -1.0           -0.055350
# 1                  -1.0           -0.055113
# 2                   1.0            0.029712
# 3                   1.0            0.050733
# 4                   1.0            0.054675
# 5                  -1.0           -0.055342
# 6                  -1.0           -0.055358
# 7                  -1.0           -0.054309
# 8                   1.0            0.034422
# 9                  -1.0           -0.047726
# 10                  1.0            0.055277
# 11                  1.0            0.040956
# 12                 -1.0           -0.055339
# 13                 -1.0           -0.055191
# 14                 -1.0           -0.055346
# 15                 -1.0           -0.055340
# 16                 -1.0           -0.047266
# 17                 -1.0           -0.034927
# 18                 -1.0           -0.055362
# 19                  1.0            0.052257

# %%
binance_df.to_csv("binance_df.csv")

# %%
# Total of weighted sentiment

total_weighted_sentiment = binance_df['weighted_sentiment'].sum()

total_weighted_sentiment
# Out:
# -0.36393577438729274

# %%
# Split the data into positive and negative

positive_binance_df = binance_df.loc[binance_df["sentiment"] == "POSITIVE"]
negative_binance_df = binance_df.loc[binance_df["sentiment"] == "NEGATIVE"]

# Filter out rows with low confidence

pos_or_neg_threshold = .80  #<-----any confidence level below this value will not be included

positive_notification_binance_df = positive_binance_df.loc[positive_binance_df["confidence"] >= pos_or_neg_threshold]
negative_notification_binance_df = negative_binance_df.loc[negative_binance_df["confidence"] >= pos_or_neg_threshold]

new_df = pd.concat([positive_binance_df, negative_binance_df])

# %%
new_df["coin_symbol"] = "BNB"
# Out:
#                                           description sentiment  confidence  \
# 2   Cryptocurrency exchange Binance on Tuesday sai...  POSITIVE    0.536603
# 3   Binance's relations with the FCA have improved...  POSITIVE    0.916237
# 4   Alethea AI and BeingAI are collaborating with ...  POSITIVE    0.987426
# 8   The wait is finally over. After a year-long de...  POSITIVE    0.621667
# 10  Binance is the largest cryptocurrency exchange...  POSITIVE    0.998292
# 11  Blockchain analytics firm Nansen on Thursday r...  POSITIVE    0.739658
# 19  If you’re looking for last-minute gift ideas, ...  POSITIVE    0.943750
# 0   The Singapore affiliate of Binance, one of the...  NEGATIVE    0.999621
# 1   Yi He, a cofounder of the cryptocurrency excha...  NEGATIVE    0.995340
# 5   "We have identified a large-scale security bre...  NEGATIVE    0.999466
# 6   "Will mongoose coin always have a value?" Sher...  NEGATIVE    0.999763
# 7   Football clubs have potentially made hundreds ...  NEGATIVE    0.980816
# 9   Coinbase Global Inc <a href="https://www.reute...  NEGATIVE    0.861919
# 12  Here are some factors that may affect Middle E...  NEGATIVE    0.999411
# 13  The cryptocurrency trading platform is suspend...  NEGATIVE    0.996753
# 14  Sheldon Xia, the founder of BitMart exchange, ...  NEGATIVE    0.999538
# 15  Here are some factors that may affect Middle E...  NEGATIVE    0.999438
# 16  The cybercriminals used a private key to acces...  NEGATIVE    0.853617
# 17  Helen Partz / Cointelegraph:\nMultichain, whic...  NEGATIVE    0.630773
# 18  People investing in the cryptocurrency should ...  NEGATIVE    0.999828
#
#     sentiment_numerical  weighted_sentiment coin_symbol
# 2                   1.0            0.029712         BNB
# 3                   1.0            0.050733         BNB
# 4                   1.0            0.054675         BNB
# 8                   1.0            0.034422         BNB
# 10                  1.0            0.055277         BNB
# 11                  1.0            0.040956         BNB
# 19                  1.0            0.052257         BNB
# 0                  -1.0           -0.055350         BNB
# 1                  -1.0           -0.055113         BNB
# 5                  -1.0           -0.055342         BNB
# 6                  -1.0           -0.055358         BNB
# 7                  -1.0           -0.054309         BNB
# 9                  -1.0           -0.047726         BNB
# 12                 -1.0           -0.055339         BNB
# 13                 -1.0           -0.055191         BNB
# 14                 -1.0           -0.055346         BNB
# 15                 -1.0           -0.055340         BNB
# 16                 -1.0           -0.047266         BNB
# 17                 -1.0           -0.034927         BNB
# 18                 -1.0           -0.055362         BNB

# %%
neutral_binance_df = binance_df

# Filter out rows with low confidence

neutral_threshold = .70  #<-----any confidence level below this value will not be included

neutral_binance_df = neutral_binance_df.loc[neutral_binance_df["confidence"] <= neutral_threshold]


neutral_binance_df["neutral"] = "NEUTRAL"

neutral_binance_df
# Out:
# C:\Users\Airma\AppData\Local\Temp/ipykernel_8416/1335408070.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   neutral_binance_df["neutral"] = "NEUTRAL"
#                                           description sentiment  confidence  \
# 2   Cryptocurrency exchange Binance on Tuesday sai...  POSITIVE    0.536603
# 8   The wait is finally over. After a year-long de...  POSITIVE    0.621667
# 17  Helen Partz / Cointelegraph:\nMultichain, whic...  NEGATIVE    0.630773
#
#     sentiment_numerical  weighted_sentiment  neutral
# 2                   1.0            0.029712  NEUTRAL
# 8                   1.0            0.034422  NEUTRAL
# 17                 -1.0           -0.034927  NEUTRAL
